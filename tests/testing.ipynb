# %%
from package import Vehicle, Trip

# %%
car = Vehicle(1993, 'Chevrolet', 'Lumina')
trip = Trip(100, 'mi', 0.55)

print(car)
print(trip)
# Out:
# Vehicle:	1993 Chevrolet Lumina
#  Transmission: Automatic
# 0.45

# %%
car.specs()
# Out:
# [{'_id': '10030',
#   'year': 1993,
#   'make': 'Chevrolet',
#   'model': 'Lumina',
#   'drivetrain': 'Front-Wheel Drive',
#   'eng_id': '4117',
#   'cylinders': '6',
#   'displacement': '3.1',
#   'displacement_measure': 'liters',
#   'fuel_source': 'single fuel',
#   'fuel_type': 'Regular',
#   'primary_fuel': 'Regular Gasoline',
#   'alt_fuel': 'none',
#   'transmission': 'Automatic 3-spd',
#   'sub_cat': 'Midsize Cars',
#   'has_mpg_data': 'Y',
#   'city_mpg_fuel1': 17,
#   'city_mpg_fuel2': 0,
#   'hwy_mpg_fuel1': 25,
#   'hwy_mpg_fuel2': 0,
#   'combined_mpg_fuel1': 20,
#   'combined_mpg_fuel2': 0},
#  {'_id': '10031',
#   'year': 1993,
#   'make': 'Chevrolet',
#   'model': 'Lumina',
#   'drivetrain': 'Front-Wheel Drive',
#   'eng_id': '4118',
#   'cylinders': '6',
#   'displacement': '3.1',
#   'displacement_measure': 'liters',
#   'fuel_source': 'single fuel',
#   'fuel_type': 'Regular',
#   'primary_fuel': 'Regular Gasoline',
#   'alt_fuel': 'none',
# ...

# %%
car.fuelConsumption(trip)
# Out:
# [{'_id': '10030',
#   'year': 1993,
#   'make': 'Chevrolet',
#   'model': 'Lumina',
#   'drivetrain': 'Front-Wheel Drive',
#   'eng_id': '4117',
#   'cylinders': '6',
#   'displacement': '3.1',
#   'displacement_measure': 'liters',
#   'fuel_source': 'single fuel',
#   'fuel_type': 'Regular',
#   'primary_fuel': 'Regular Gasoline',
#   'alt_fuel': 'none',
#   'transmission': 'Automatic 3-spd',
#   'sub_cat': 'Midsize Cars',
#   'has_mpg_data': 'Y',
#   'city_mpg_fuel1': 17,
#   'city_mpg_fuel2': 0,
#   'hwy_mpg_fuel1': 25,
#   'hwy_mpg_fuel2': 0,
#   'combined_mpg_fuel1': 20,
#   'combined_mpg_fuel2': 0,
#   'est_consumption_gal': 5.04},
#  {'_id': '10031',
#   'year': 1993,
#   'make': 'Chevrolet',
#   'model': 'Lumina',
#   'drivetrain': 'Front-Wheel Drive',
#   'eng_id': '4118',
#   'cylinders': '6',
#   'displacement': '3.1',
#   'displacement_measure': 'liters',
#   'fuel_source': 'single fuel',
#   'fuel_type': 'Regular',
#   'primary_fuel': 'Regular Gasoline',
# ...
